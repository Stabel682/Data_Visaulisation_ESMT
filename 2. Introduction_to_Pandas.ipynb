# %% [markdown]
# # Pandas for Data Analysis

# %% [markdown]
# [**Pandas**](https://pandas.pydata.org/) is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# We will first introduce some core aspects of pandas using toy data, and then analyse a real data set. First, we should import the pandas package - by convention we give it a shorthand name using `as`. When we want to use the package, we can type `pd.` instead of `pandas.`.
#
# #### Useful links
# * [Data Wrangling cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# * [Python For Data Science cheat sheet](https://www.utc.fr/~jlaforet/Suppl/python-cheatsheets.pdf)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Creating and Reading Data
#
# Two core objects in pandas: **Series** and **DataFrame**.
#
# [**Series**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html) is a one-dimensional (1d) *list* of values. It has a corresponding list of *index* and (possibly) a *name*.

# %%
pd.Series([12,15,18], index = [2020, 2021, 2022], name = "Sales")
# Out:
# 2020    12
# 2021    15
# 2022    18
# Name: Sales, dtype: int64

# %% [markdown]
# [**DataFrame**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame) is a two-dimensional (2d) *table* of values. Each row is a "record" having its *index* and each column is a **Series** having its (column) *name*.

# %%
df = pd.DataFrame({'date': pd.date_range('31/05/2022', periods = 5, freq = 'ME'), 
             'sales': [300, 313, 330, 350,400],
             'department':'Technology'})

# %% [markdown]
# **Checking the DataFrame index**
#
# - The index is how Pandas labels and organizes the rows in your DataFrame.
# - Knowing the index is important because it tells you how you can access, align, or join your data.

# %%
df.set_index('date', inplace =True)
df
# Out:
#             sales  department
# date
# 2022-05-31    300  Technology
# 2022-06-30    313  Technology
# 2022-07-31    330  Technology
# 2022-08-31    350  Technology
# 2022-09-30    400  Technology

# %% [markdown]
# **Setting a column as the index**
# - Makes it easier to work with time series data, since dates are now row labels.

# %%
df.reset_index()
# Out:
#         date  sales  department
# 0 2022-05-31    300  Technology
# 1 2022-06-30    313  Technology
# 2 2022-07-31    330  Technology
# 3 2022-08-31    350  Technology
# 4 2022-09-30    400  Technology

# %% [markdown]
# **We can also reset the index**

# %%
df.columns
# Out:
# Index(['sales', 'department'], dtype='object')

# %% [markdown]
# **Checking the Datafram columns**
# - Lists all column labels in the DataFrame.
# - Useful for quickly checking the structure of your dataset.

# %% [markdown]
# ### Exercise
#
# 1. Create a dataframe called sales that matches the diagram below
#
# | week       | electronics_sales | furniture_sales |
# |------------|-------------------|-----------------|
# | 2022-06-05 | 120               | 85              |
# | 2022-06-12 | 135               | 90              |
# | 2022-06-19 | 128               | 88              |
# | 2022-06-26 | 150               | 95              |
#
# 2. Display the sales dataframe
# 3. Set the `week` column as index

# %%
# Step 1: Create DataFrame
df = pd.DataFrame({'week': pd.date_range('05/06/2022', periods = 4, freq = 'ME'), 
                   'electronic_sales': [120, 135, 128, 150],
                   'furniture_sales': [85, 90,88,95],})

# Step 2: Display the DataFrame
df 

# Step 3: Set 'week' as index

df.set_index('week', inplace =True)
# Display final DataFrame
df
# Out:
#             electronic_sales  furniture_sales
# week
# 2022-05-31               120               85
# 2022-06-30               135               90
# 2022-07-31               128               88
# 2022-08-31               150               95

# %% [markdown]
# More often, DataFrames are created from data files, like **CSV (comma-separated values)** files, using [`pd.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) function.
#
# **Let's import our first dataframe**

# %%
reviews = pd.read_csv('../Data/wine_reviews.csv', index_col = 0)

# %%
reviews = reviews.reset_index(drop =True)

# %% [markdown]
# ### Viewing, Selecting, Assigning & Missing Data

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
reviews.tail
# Out:
# <bound method NDFrame.tail of          country                                        description  \
# 0      Australia  Possibly a little sweet, this is a soft, easyg...
# 1         France  A soft, almost off dry wine that is full in th...
# 2          Spain  Generic white-fruit aromas of peach and apple ...
# 3             US  This is the winery's best Nebula in years. Whi...
# 4             US  This is a very rich Pinot whose primary virtue...
# ...          ...                                                ...
# 58482         US  A solid effort from a dependable winery that u...
# 58483     Greece  Crushed thyme, pine resin and lemon start this...
# 58484      Italy  Made from Negroamaro, this opens with aromas o...
# 58485         US  This big, bold wine has the taste profile of a...
# 58486      Spain  Zingy and sort of floral on the nose, but fair...
#
#                                designation  points  price         province  \
# 0                                      NaN      83    5.0  Australia Other
# 1                                  Réserve      85   12.0     Rhône Valley
# 2                   Estate Grown & Bottled      86    9.0   Northern Spain
# 3                                   Nebula      87   29.0       California
# 4                           Wiley Vineyard      88   40.0       California
# ...                                    ...     ...    ...              ...
# 58482                  Winemaker's Reserve      88   35.0       California
# 58483                    Retsina of Attica      86    9.0           Attica
# 58484                                  NaN      87   15.0   Southern Italy
# 58485  Estate Mae's Block Ravazzi Vineyard      88   32.0       California
# 58486                               Blanco      82   10.0    Central Spain
#
#                       region_1       region_2        taster_name  \
# 0      South Eastern Australia            NaN     Joe Czerwinski
# 1               Côtes du Rhône            NaN         Roger Voss
# 2                        Rueda            NaN  Michael Schachner
# 3                  Paso Robles  Central Coast                NaN
# 4              Anderson Valley            NaN                NaN
# ...                        ...            ...                ...
# 58482            Sonoma County         Sonoma                NaN
# 58483                      NaN            NaN    Susan Kostrzewa
# 58484                  Salento            NaN      Kerin O’Keefe
# 58485                Mendocino            NaN         Jim Gordon
# 58486                La Mancha            NaN  Michael Schachner
#
#       taster_twitter_handle  \
# 0                    @JoeCz
# 1                @vossroger
# 2               @wineschach
# 3                       NaN
# 4                       NaN
# ...                     ...
# 58482                   NaN
# 58483         @suskostrzewa
# 58484          @kerinokeefe
# 58485      @gordone_cellars
# 58486           @wineschach
#
#                                                    title             variety  \
# 0      Banrock Station 2006 Chardonnay (South Eastern...          Chardonnay
# 1      Cellier des Dauphins 2015 Réserve Rosé (Côtes ...                Rosé
# 2      Esperanza 2013 Estate Grown & Bottled Verdejo-...       Verdejo-Viura
# 3      Midnight 2010 Nebula Cabernet Sauvignon (Paso ...  Cabernet Sauvignon
# 4      Harrington 2006 Wiley Vineyard Pinot Noir (And...          Pinot Noir
# ...                                                  ...                 ...
# 58482  Château Souverain 1996 Winemaker's Reserve Cab...  Cabernet Sauvignon
# 58483   Kourtaki NV Retsina of Attica Savatiano (Attica)           Savatiano
# 58484            Masseria Altemura 2016 Rosato (Salento)              Rosato
# 58485  Jaxon Keys 2013 Estate Mae's Block Ravazzi Vin...           Zinfandel
# 58486        Finca Antigua 2006 Blanco Viura (La Mancha)               Viura
#
#                      winery
# 0           Banrock Station
# 1      Cellier des Dauphins
# 2                 Esperanza
# 3                  Midnight
# 4                Harrington
# ...                     ...
# 58482     Château Souverain
# 58483              Kourtaki
# 58484     Masseria Altemura
# 58485            Jaxon Keys
# 58486         Finca Antigua
#
# [58487 rows x 13 columns]>

# %%
reviews.head()
# Out:
#      country                                        description  \
# 0  Australia  Possibly a little sweet, this is a soft, easyg...
# 1     France  A soft, almost off dry wine that is full in th...
# 2      Spain  Generic white-fruit aromas of peach and apple ...
# 3         US  This is the winery's best Nebula in years. Whi...
# 4         US  This is a very rich Pinot whose primary virtue...
#
#               designation  points  price         province  \
# 0                     NaN      83    5.0  Australia Other
# 1                 Réserve      85   12.0     Rhône Valley
# 2  Estate Grown & Bottled      86    9.0   Northern Spain
# 3                  Nebula      87   29.0       California
# 4          Wiley Vineyard      88   40.0       California
#
#                   region_1       region_2        taster_name  \
# 0  South Eastern Australia            NaN     Joe Czerwinski
# 1           Côtes du Rhône            NaN         Roger Voss
# 2                    Rueda            NaN  Michael Schachner
# 3              Paso Robles  Central Coast                NaN
# 4          Anderson Valley            NaN                NaN
#
#   taster_twitter_handle                                              title  \
# 0                @JoeCz  Banrock Station 2006 Chardonnay (South Eastern...
# 1            @vossroger  Cellier des Dauphins 2015 Réserve Rosé (Côtes ...
# 2           @wineschach  Esperanza 2013 Estate Grown & Bottled Verdejo-...
# 3                   NaN  Midnight 2010 Nebula Cabernet Sauvignon (Paso ...
# 4                   NaN  Harrington 2006 Wiley Vineyard Pinot Noir (And...
#
#               variety                winery
# 0          Chardonnay       Banrock Station
# 1                Rosé  Cellier des Dauphins
# 2       Verdejo-Viura             Esperanza
# 3  Cabernet Sauvignon              Midnight
# 4          Pinot Noir            Harrington

# %% [markdown]
# ### Selecting Data
#
# Also called **indexing**, it is the most common operation in Pandas. We discuss 4 cases selecting data from a DataFrame:
# 1. Selecting one **column** (as a Series)
# 2. Selecting by **label**
# 3. Selecting by **position**
# 4. Selecting by **conditions**
#
# We will practice with the wine review DataFrame.

# %%
reviews.country
# Out:
# 0        Australia
# 1           France
# 2            Spain
# 3               US
# 4               US
#            ...
# 58482           US
# 58483       Greece
# 58484        Italy
# 58485           US
# 58486        Spain
# Name: country, Length: 58487, dtype: object

# %% [markdown]
# **1. Selecting a column**

# %% [markdown]
# **2. Selecting by label**
#
# Here "label" means the "row names" `index` and the "column names" `columns`.

# %%
print(reviews.index)
print(reviews.columns)
# Out:
# RangeIndex(start=0, stop=58487, step=1)
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# Use `loc[]` to access part of the DataFrame by row and column **labels**. Note the `[]` instead of `()`.

# %%
review.loc[1,'country']

# %% [markdown]
# We can use `:` inside `.loc[]` to access either all rows for a given column(s)

# %%
reviews.loc[:,'country'] # all
reviews.loc[0:50,'country'] #range
reviews.loc[:,['country', 'province']] #diffent columns
# Out:
#          country         province
# 0      Australia  Australia Other
# 1         France     Rhône Valley
# 2          Spain   Northern Spain
# 3             US       California
# 4             US       California
# ...          ...              ...
# 58482         US       California
# 58483     Greece           Attica
# 58484      Italy   Southern Italy
# 58485         US       California
# 58486      Spain    Central Spain
#
# [58487 rows x 2 columns]

# %% [markdown]
# We can rearrange our `.loc[]` to obtain all columns for specif range of rows too!

# %%
reviews.loc[15:25, :]
# Out:
#       country                                        description  \
# 15      Italy  Baked plum, blue flower, dark spice, vanilla a...
# 16         US  The winery says this high-alcohol wine, made f...
# 17    Germany  Hints of lemon shortbread, fresh apple and whi...
# 18      Italy  Notes of cherry and raspberry open the nose of...
# 19         US  A blend of Ciel du Cheval and Force Majeure vi...
# 20      Chile  Fleshy, tropical aromas with a touch of variet...
# 21  Australia  This restrained, medium-bodied Cabernet Sauvig...
# 22         US  Intense perfume and floral notes overcome ripe...
# 23         US  This cool climate region is well-suited to thi...
# 24   Portugal  A soft apple-tinged wine, with bright acidity ...
# 25      Italy  Here's a Pinot Grigio that ranks high in terms...
#
#                                designation  points  price            province  \
# 15                              Caleno Oro      88    NaN      Southern Italy
# 16                            Dessert Wine      86   20.0          California
# 17                             Dom Off-Dry      89   18.0               Mosel
# 18                                 Vriccio      86   20.0      Southern Italy
# 19                              Crazy Mary      93   48.0          Washington
# 20                          U Estate Grown      85   11.0        Maipo Valley
# 21                            Two Passions      90   20.0   Western Australia
# 22                                     NaN      83   25.0            New York
# 23                             Gorge Crest      90   28.0              Oregon
# 24  Conde de Vimioso Colheita Seleccionada      86    9.0                Tejo
# 25                                     NaN      87   17.0  Northeastern Italy
#
#                      region_1          region_2         taster_name  \
# 15                   Campania               NaN       Kerin O’Keefe
# 16                 California  California Other                 NaN
# 17                        NaN               NaN  Anna Lee C. Iijima
# 18                     Puglia               NaN                 NaN
# 19               Red Mountain   Columbia Valley    Sean P. Sullivan
# 20                        NaN               NaN   Michael Schachner
# 21             Margaret River               NaN      Joe Czerwinski
# 22  North Fork of Long Island       Long Island  Anna Lee C. Iijima
# 23        Columbia Gorge (OR)      Oregon Other        Paul Gregutt
# 24                        NaN               NaN          Roger Voss
# 25                 Alto Adige               NaN                 NaN
#
#    taster_twitter_handle                                              title  \
# 15          @kerinokeefe        Nugnes 2009 Caleno Oro Aglianico (Campania)
# 16                   NaN    Elkhorn Peak NV Dessert Wine White (California)
# 17                   NaN  Bischöfliche Weingüter Trier 2015 Dom Off-Dry ...
# 18                   NaN     Antica Enotria 2011 Vriccio Primitivo (Puglia)
# 19         @wawinereport  Mark Ryan 2012 Crazy Mary Mourvèdre (Red Mount...
# 20           @wineschach  Undurraga 2012 U Estate Grown Sauvignon Blanc ...
# 21                @JoeCz  Wildberry Estate 2013 Two Passions Cabernet Sa...
# 22                   NaN   Palmer 2012 Albariño (North Fork of Long Island)
# 23           @paulgwine   Phelps Creek 2015 Gorge Crest Gewürztraminer (...
# 24            @vossroger  Falua 2010 Conde de Vimioso Colheita Seleccion...
# 25                   NaN          Erste Neue 2011 Pinot Grigio (Alto Adige)
#
#                variety                        winery
# 15           Aglianico                        Nugnes
# 16         White Blend                  Elkhorn Peak
# 17            Riesling  Bischöfliche Weingüter Trier
# 18           Primitivo                Antica Enotria
# 19           Mourvèdre                     Mark Ryan
# 20     Sauvignon Blanc                     Undurraga
# 21  Cabernet Sauvignon              Wildberry Estate
# 22            Albariño                        Palmer
# 23      Gewürztraminer                  Phelps Creek
# 24    Portuguese White                         Falua
# 25        Pinot Grigio                    Erste Neue

# %% [markdown]
# We can use the `:` inside `.loc[]` to obtain a range from a specific point until the end of the dataframe

# %%
reviews.loc[10500:,'country' : 'province']
# Out:
#        country                                        description  \
# 10500    Spain  Fleshy stone-fruit aromas announce a fuller-bo...
# 10501   France  The tannins of the vintage are very apparent i...
# 10502    Chile  Jammy raspberry aromas lack focus; the bouquet...
# 10503  Austria  The scent of ripe, red-cheeked apples perfumes...
# 10504       US  Heady, gamy and thick notes of lanolin, blood,...
# ...        ...                                                ...
# 58482       US  A solid effort from a dependable winery that u...
# 58483   Greece  Crushed thyme, pine resin and lemon start this...
# 58484    Italy  Made from Negroamaro, this opens with aromas o...
# 58485       US  This big, bold wine has the taste profile of a...
# 58486    Spain  Zingy and sort of floral on the nose, but fair...
#
#                                designation  points  price          province
# 10500                               Rosado      86   10.0    Northern Spain
# 10501                                  NaN      87   25.0          Bordeaux
# 10502                                  NaN      83   14.0    Central Valley
# 10503                      Gemischter Satz      89   21.0  Niederösterreich
# 10504                               Estate      93   46.0        California
# ...                                    ...     ...    ...               ...
# 58482                  Winemaker's Reserve      88   35.0        California
# 58483                    Retsina of Attica      86    9.0            Attica
# 58484                                  NaN      87   15.0    Southern Italy
# 58485  Estate Mae's Block Ravazzi Vineyard      88   32.0        California
# 58486                               Blanco      82   10.0     Central Spain
#
# [47987 rows x 6 columns]

# %% [markdown]
# **3. Selecting by position**
#
# Here "position" means the *numerical location*, i.e., row number and column number (both start from 0 per Python convention), in the DataFrame.
#
# Use `iloc[]` to access part of the DataFrame by row and column numbers. Note the `[]` instead of `()`.

# %%
reviews.iloc[1,0]
# Out:
# 'France'

# %% [raw]
# reviews.iloc[2:6, :]

# %%
reviews.iloc[:,0:5]
# Out:
#               country                                        description  \
# Unnamed: 0
# 77718       Australia  Possibly a little sweet, this is a soft, easyg...
# 67681          France  A soft, almost off dry wine that is full in th...
# 69877           Spain  Generic white-fruit aromas of peach and apple ...
# 46544              US  This is the winery's best Nebula in years. Whi...
# 186                US  This is a very rich Pinot whose primary virtue...
# ...               ...                                                ...
# 43857              US  A solid effort from a dependable winery that u...
# 87060          Greece  Crushed thyme, pine resin and lemon start this...
# 96141           Italy  Made from Negroamaro, this opens with aromas o...
# 75013              US  This big, bold wine has the taste profile of a...
# 106613          Spain  Zingy and sort of floral on the nose, but fair...
#
#                                     designation  points  price
# Unnamed: 0
# 77718                                       NaN      83    5.0
# 67681                                   Réserve      85   12.0
# 69877                    Estate Grown & Bottled      86    9.0
# 46544                                    Nebula      87   29.0
# 186                              Wiley Vineyard      88   40.0
# ...                                         ...     ...    ...
# 43857                       Winemaker's Reserve      88   35.0
# 87060                         Retsina of Attica      86    9.0
# 96141                                       NaN      87   15.0
# 75013       Estate Mae's Block Ravazzi Vineyard      88   32.0
# 106613                                   Blanco      82   10.0
#
# [58487 rows x 5 columns]

# %% [markdown]
# **4. Selecting by conditions**
#
# This is also called **boolean indexing**, usually used to select *rows* satisfying certain conditions.

# %%
reviews.loc[reviews.country == 'France']
# Out:
#            country                                        description  \
# Unnamed: 0
# 67681       France  A soft, almost off dry wine that is full in th...
# 56015       France  Made from low-yielding, 70-year-old vines, thi...
# 41016       France  This ripe, fruity wine has both freshness and ...
# 81019       France  This is a smooth and creamy wine with soft app...
# 129599      France  This is pretty pale for a Tavel, with a copper...
# ...            ...                                                ...
# 124417      France  Just hinting at maturity, this rich and stylis...
# 21369       France  This wine is crisp and refreshingly fruity. A ...
# 109686      France  The dry character of this wine is emphasized b...
# 50237       France  This wine comes from the stony slopes above th...
# 105774      France  Soft, warm and smoky wine, this has a finely l...
#
#                       designation  points  price          province  \
# Unnamed: 0
# 67681                     Réserve      85   12.0      Rhône Valley
# 56015             Clos du Château      92   21.0          Provence
# 41016       Réserve des Vignerons      86   14.0      Loire Valley
# 81019             Clos le Vigneau      90   18.0      Loire Valley
# 129599                        NaN      90   24.0      Rhône Valley
# ...                           ...     ...    ...               ...
# 124417                        NaN      90   40.0          Bordeaux
# 21369                         NaN      85   16.0          Burgundy
# 109686                        NaN      85   11.0            Alsace
# 50237                 Renaissance      93   23.0  Southwest France
# 105774                        NaN      87   16.0          Bordeaux
#
#                                region_1 region_2     taster_name  \
# Unnamed: 0
# 67681                    Côtes du Rhône      NaN      Roger Voss
# 56015                 Côtes de Provence      NaN      Roger Voss
# 41016                            Saumur      NaN      Roger Voss
# 81019                           Vouvray      NaN      Roger Voss
# 129599                            Tavel      NaN  Joe Czerwinski
# ...                                 ...      ...             ...
# 124417                    Canon-Fronsac      NaN      Roger Voss
# 21369                    Mâcon-Villages      NaN      Roger Voss
# 109686                           Alsace      NaN      Roger Voss
# 50237                           Gaillac      NaN      Roger Voss
# 105774      Castillon Côtes de Bordeaux      NaN      Roger Voss
#
#            taster_twitter_handle  \
# Unnamed: 0
# 67681                 @vossroger
# 56015                 @vossroger
# 41016                 @vossroger
# 81019                 @vossroger
# 129599                    @JoeCz
# ...                          ...
# 124417                @vossroger
# 21369                 @vossroger
# 109686                @vossroger
# 50237                 @vossroger
# 105774                @vossroger
#
#                                                         title  \
# Unnamed: 0
# 67681       Cellier des Dauphins 2015 Réserve Rosé (Côtes ...
# 56015       Domaine du Clos Gautier 2015 Clos du Château R...
# 41016       Cave de Saumur 2014 Réserve des Vignerons  (Sa...
# 81019       Château Gaudrelle 2010 Clos le Vigneau  (Vouvray)
# 129599                    Prieuré de Montézargues 2014  Tavel
# ...                                                       ...
# 124417                      Château Canon 2005  Canon-Fronsac
# 21369                     Joseph Drouhin 2016  Mâcon-Villages
# 109686              Cave de Hunawihr 2013 Pinot Gris (Alsace)
# 50237           Domaine Rotier 2015 Renaissance Red (Gaillac)
# 105774      Château Moulin de Clotte 2009  Castillon Côtes...
#
#                              variety                    winery
# Unnamed: 0
# 67681                           Rosé      Cellier des Dauphins
# 56015                           Rosé   Domaine du Clos Gautier
# 41016                   Chenin Blanc            Cave de Saumur
# 81019                   Chenin Blanc         Château Gaudrelle
# 129599                          Rosé   Prieuré de Montézargues
# ...                              ...                       ...
# 124417      Bordeaux-style Red Blend             Château Canon
# 21369                     Chardonnay            Joseph Drouhin
# 109686                    Pinot Gris          Cave de Hunawihr
# 50237                      Red Blend            Domaine Rotier
# 105774      Bordeaux-style Red Blend  Château Moulin de Clotte
#
# [9998 rows x 13 columns]

# %% [markdown]
# How can we satisfy more than one condition?
#
# We still need `[]` as we are passing a list of labels or conditions.
#
# We can seprate our conditions using the `&`.
#
# We will also need wrap our conditions using `()` due to precedence.
#
# In python `==` have a higher precedence than bitwise operators like `&`.
#
# So we need any `==` to be evaluated first and then combined.

# %%
reviews.loc[(reviews.country == 'France') & (reviews.points >= 95)]
# Out:
#            country                                        description  \
# Unnamed: 0
# 73985       France  A gorgeously perfumed wine, dominated by the r...
# 84808       France  This wine has power along with great fruit and...
# 124435      France  The wood element is important here, but it is ...
# 89734       France  The wine from this clos or walled vineyard in ...
# 84820       France  Produced from vines mainly planted in the 1970...
# ...            ...                                                ...
# 16106       France  96–98. Barrel sample. This powerful, impressiv...
# 99326       France  The heady scent of Damask rose hints unmistaka...
# 36205       France  This is a full-bodied and ripe wine, showing s...
# 52894       France  Toasty aromas are not enough to smother the in...
# 63860       France  94–96. Barrel sample. This is a powerful wine ...
#
#                            designation  points  price   province  \
# Unnamed: 0
# 73985                              NaN      95  295.0   Bordeaux
# 84808                              NaN      95  185.0   Burgundy
# 124435                             NaN      95  450.0   Bordeaux
# 89734                      Clos Lanson      96  196.0  Champagne
# 84820                              NaN      95  973.0   Burgundy
# ...                                ...     ...    ...        ...
# 16106                    Barrel Sample      97    NaN   Bordeaux
# 99326       Grand Cru Pfersigberg Doux      95   90.0     Alsace
# 36205                Belle Epoque Brut      95  150.0  Champagne
# 52894                              NaN      95  307.0   Burgundy
# 63860                    Barrel Sample      95    NaN   Bordeaux
#
#                       region_1 region_2       taster_name  \
# Unnamed: 0
# 73985            Saint-Émilion      NaN        Roger Voss
# 84808       Corton-Charlemagne      NaN        Roger Voss
# 124435                Pauillac      NaN        Roger Voss
# 89734                Champagne      NaN        Roger Voss
# 84820                  Musigny      NaN        Roger Voss
# ...                        ...      ...               ...
# 16106                 Pauillac      NaN        Roger Voss
# 99326                   Alsace      NaN  Anne Krebiehl MW
# 36205                Champagne      NaN        Roger Voss
# 52894          Clos de Vougeot      NaN        Roger Voss
# 63860            Saint-Émilion      NaN        Roger Voss
#
#            taster_twitter_handle  \
# Unnamed: 0
# 73985                 @vossroger
# 84808                 @vossroger
# 124435                @vossroger
# 89734                 @vossroger
# 84820                 @vossroger
# ...                          ...
# 16106                 @vossroger
# 99326                @AnneInVino
# 36205                 @vossroger
# 52894                 @vossroger
# 63860                 @vossroger
#
#                                                         title  \
# Unnamed: 0
# 73985                             Le Dôme 2009  Saint-Émilion
# 84808                  Albert Bichot 2014  Corton-Charlemagne
# 124435               Château Mouton Rothschild 2007  Pauillac
# 89734          Lanson 2006 Clos Lanson Chardonnay (Champagne)
# 84820                    Domaine Jacques Prieur 2014  Musigny
# ...                                                       ...
# 16106       Château Mouton Rothschild 2012 Barrel Sample  ...
# 99326       Domaine Barmès-Buecher 2013 Grand Cru Pfersigb...
# 36205       Perrier Jouët 2006 Belle Epoque Brut  (Champagne)
# 52894               Domaine Méo-Camuzet 2013  Clos de Vougeot
# 63860       Château Pavie 2012 Barrel Sample  (Saint-Émilion)
#
#                              variety                     winery
# Unnamed: 0
# 73985       Bordeaux-style Red Blend                    Le Dôme
# 84808                     Chardonnay              Albert Bichot
# 124435      Bordeaux-style Red Blend  Château Mouton Rothschild
# 89734                     Chardonnay                     Lanson
# 84820                     Pinot Noir     Domaine Jacques Prieur
# ...                              ...                        ...
# 16106       Bordeaux-style Red Blend  Château Mouton Rothschild
# 99326                 Gewürztraminer     Domaine Barmès-Buecher
# 36205                Champagne Blend              Perrier Jouët
# 52894                     Pinot Noir        Domaine Méo-Camuzet
# 63860       Bordeaux-style Red Blend              Château Pavie
#
# [332 rows x 13 columns]

# %%
reviews.loc[(reviews.country == 'France') & (reviews.points >= 95), ['country', 'description', 'points', 'price']]
# Out:
#            country                                        description  points  \
# Unnamed: 0
# 73985       France  A gorgeously perfumed wine, dominated by the r...      95
# 84808       France  This wine has power along with great fruit and...      95
# 124435      France  The wood element is important here, but it is ...      95
# 89734       France  The wine from this clos or walled vineyard in ...      96
# 84820       France  Produced from vines mainly planted in the 1970...      95
# ...            ...                                                ...     ...
# 16106       France  96–98. Barrel sample. This powerful, impressiv...      97
# 99326       France  The heady scent of Damask rose hints unmistaka...      95
# 36205       France  This is a full-bodied and ripe wine, showing s...      95
# 52894       France  Toasty aromas are not enough to smother the in...      95
# 63860       France  94–96. Barrel sample. This is a powerful wine ...      95
#
#             price
# Unnamed: 0
# 73985       295.0
# 84808       185.0
# 124435      450.0
# 89734       196.0
# 84820       973.0
# ...           ...
# 16106         NaN
# 99326        90.0
# 36205       150.0
# 52894       307.0
# 63860         NaN
#
# [332 rows x 4 columns]

# %% [markdown]
# We can also satisfy 2 conditions within a column using `.isin()` and passing it a list

# %%
reviews.loc[reviews.country.isin(['France','Italy'])]
# Out:
#            country                                        description  \
# Unnamed: 0
# 67681       France  A soft, almost off dry wine that is full in th...
# 80832        Italy  Made with 100% Chardonnay, this creamy sparkle...
# 56015       France  Made from low-yielding, 70-year-old vines, thi...
# 41016       France  This ripe, fruity wine has both freshness and ...
# 81019       France  This is a smooth and creamy wine with soft app...
# ...            ...                                                ...
# 109686      France  The dry character of this wine is emphasized b...
# 50237       France  This wine comes from the stony slopes above th...
# 105774      France  Soft, warm and smoky wine, this has a finely l...
# 38963        Italy  Menthol, eucalyptus, violet, berry, clove and ...
# 96141        Italy  Made from Negroamaro, this opens with aromas o...
#
#                       designation  points  price          province  \
# Unnamed: 0
# 67681                     Réserve      85   12.0      Rhône Valley
# 80832                       Saten      89   35.0          Lombardy
# 56015             Clos du Château      92   21.0          Provence
# 41016       Réserve des Vignerons      86   14.0      Loire Valley
# 81019             Clos le Vigneau      90   18.0      Loire Valley
# ...                           ...     ...    ...               ...
# 109686                        NaN      85   11.0            Alsace
# 50237                 Renaissance      93   23.0  Southwest France
# 105774                        NaN      87   16.0          Bordeaux
# 38963                 Castelletto      94   50.0          Piedmont
# 96141                         NaN      87   15.0    Southern Italy
#
#                                region_1 region_2    taster_name  \
# Unnamed: 0
# 67681                    Côtes du Rhône      NaN     Roger Voss
# 80832                      Franciacorta      NaN  Kerin O’Keefe
# 56015                 Côtes de Provence      NaN     Roger Voss
# 41016                            Saumur      NaN     Roger Voss
# 81019                           Vouvray      NaN     Roger Voss
# ...                                 ...      ...            ...
# 109686                           Alsace      NaN     Roger Voss
# 50237                           Gaillac      NaN     Roger Voss
# 105774      Castillon Côtes de Bordeaux      NaN     Roger Voss
# 38963                            Barolo      NaN  Kerin O’Keefe
# 96141                           Salento      NaN  Kerin O’Keefe
#
#            taster_twitter_handle  \
# Unnamed: 0
# 67681                 @vossroger
# 80832               @kerinokeefe
# 56015                 @vossroger
# 41016                 @vossroger
# 81019                 @vossroger
# ...                          ...
# 109686                @vossroger
# 50237                 @vossroger
# 105774                @vossroger
# 38963               @kerinokeefe
# 96141               @kerinokeefe
#
#                                                         title  \
# Unnamed: 0
# 67681       Cellier des Dauphins 2015 Réserve Rosé (Côtes ...
# 80832       Lantieri de Paratico NV Saten Chardonnay (Fran...
# 56015       Domaine du Clos Gautier 2015 Clos du Château R...
# 41016       Cave de Saumur 2014 Réserve des Vignerons  (Sa...
# 81019       Château Gaudrelle 2010 Clos le Vigneau  (Vouvray)
# ...                                                       ...
# 109686              Cave de Hunawihr 2013 Pinot Gris (Alsace)
# 50237           Domaine Rotier 2015 Renaissance Red (Gaillac)
# 105774      Château Moulin de Clotte 2009  Castillon Côtes...
# 38963                 Mauro Veglio 2010 Castelletto  (Barolo)
# 96141                 Masseria Altemura 2016 Rosato (Salento)
#
#                              variety                    winery
# Unnamed: 0
# 67681                           Rosé      Cellier des Dauphins
# 80832                     Chardonnay      Lantieri de Paratico
# 56015                           Rosé   Domaine du Clos Gautier
# 41016                   Chenin Blanc            Cave de Saumur
# 81019                   Chenin Blanc         Château Gaudrelle
# ...                              ...                       ...
# 109686                    Pinot Gris          Cave de Hunawihr
# 50237                      Red Blend            Domaine Rotier
# 105774      Bordeaux-style Red Blend  Château Moulin de Clotte
# 38963                       Nebbiolo              Mauro Veglio
# 96141                         Rosato         Masseria Altemura
#
# [18855 rows x 13 columns]

# %% [markdown]
# Missing values can also be considered as conditions

# %%
reviews.loc[reviews.price.isnull()]
reviews.loc[reviews.price.notnull()]
# Out:
#               country                                        description  \
# Unnamed: 0
# 77718       Australia  Possibly a little sweet, this is a soft, easyg...
# 67681          France  A soft, almost off dry wine that is full in th...
# 69877           Spain  Generic white-fruit aromas of peach and apple ...
# 46544              US  This is the winery's best Nebula in years. Whi...
# 186                US  This is a very rich Pinot whose primary virtue...
# ...               ...                                                ...
# 43857              US  A solid effort from a dependable winery that u...
# 87060          Greece  Crushed thyme, pine resin and lemon start this...
# 96141           Italy  Made from Negroamaro, this opens with aromas o...
# 75013              US  This big, bold wine has the taste profile of a...
# 106613          Spain  Zingy and sort of floral on the nose, but fair...
#
#                                     designation  points  price  \
# Unnamed: 0
# 77718                                       NaN      83    5.0
# 67681                                   Réserve      85   12.0
# 69877                    Estate Grown & Bottled      86    9.0
# 46544                                    Nebula      87   29.0
# 186                              Wiley Vineyard      88   40.0
# ...                                         ...     ...    ...
# 43857                       Winemaker's Reserve      88   35.0
# 87060                         Retsina of Attica      86    9.0
# 96141                                       NaN      87   15.0
# 75013       Estate Mae's Block Ravazzi Vineyard      88   32.0
# 106613                                   Blanco      82   10.0
#
#                    province                 region_1       region_2  \
# Unnamed: 0
# 77718       Australia Other  South Eastern Australia            NaN
# 67681          Rhône Valley           Côtes du Rhône            NaN
# 69877        Northern Spain                    Rueda            NaN
# 46544            California              Paso Robles  Central Coast
# 186              California          Anderson Valley            NaN
# ...                     ...                      ...            ...
# 43857            California            Sonoma County         Sonoma
# 87060                Attica                      NaN            NaN
# 96141        Southern Italy                  Salento            NaN
# 75013            California                Mendocino            NaN
# 106613        Central Spain                La Mancha            NaN
#
#                   taster_name taster_twitter_handle  \
# Unnamed: 0
# 77718          Joe Czerwinski                @JoeCz
# 67681              Roger Voss            @vossroger
# 69877       Michael Schachner           @wineschach
# 46544                     NaN                   NaN
# 186                       NaN                   NaN
# ...                       ...                   ...
# 43857                     NaN                   NaN
# 87060         Susan Kostrzewa         @suskostrzewa
# 96141           Kerin O’Keefe          @kerinokeefe
# 75013              Jim Gordon      @gordone_cellars
# 106613      Michael Schachner           @wineschach
#
#                                                         title  \
# Unnamed: 0
# 77718       Banrock Station 2006 Chardonnay (South Eastern...
# 67681       Cellier des Dauphins 2015 Réserve Rosé (Côtes ...
# 69877       Esperanza 2013 Estate Grown & Bottled Verdejo-...
# 46544       Midnight 2010 Nebula Cabernet Sauvignon (Paso ...
# 186         Harrington 2006 Wiley Vineyard Pinot Noir (And...
# ...                                                       ...
# 43857       Château Souverain 1996 Winemaker's Reserve Cab...
# 87060        Kourtaki NV Retsina of Attica Savatiano (Attica)
# 96141                 Masseria Altemura 2016 Rosato (Salento)
# 75013       Jaxon Keys 2013 Estate Mae's Block Ravazzi Vin...
# 106613            Finca Antigua 2006 Blanco Viura (La Mancha)
#
#                        variety                winery
# Unnamed: 0
# 77718               Chardonnay       Banrock Station
# 67681                     Rosé  Cellier des Dauphins
# 69877            Verdejo-Viura             Esperanza
# 46544       Cabernet Sauvignon              Midnight
# 186                 Pinot Noir            Harrington
# ...                        ...                   ...
# 43857       Cabernet Sauvignon     Château Souverain
# 87060                Savatiano              Kourtaki
# 96141                   Rosato     Masseria Altemura
# 75013                Zinfandel            Jaxon Keys
# 106613                   Viura         Finca Antigua
#
# [54404 rows x 13 columns]

# %% [markdown]
# #### Missing Data
#
# Detect missing data `np.nan`:

# %%
reviews.isna().any()
# Out:
# country                   True
# description              False
# designation               True
# points                   False
# price                     True
# province                  True
# region_1                  True
# region_2                  True
# taster_name               True
# taster_twitter_handle     True
# title                    False
# variety                  False
# winery                   False
# dtype: bool

# %% [markdown]
# Filling in missing data

# %%
reviews.fillna(1).isna().any()
# Out:
# country                  False
# description              False
# designation              False
# points                   False
# price                    False
# province                 False
# region_1                 False
# region_2                 False
# taster_name              False
# taster_twitter_handle    False
# title                    False
# variety                  False
# winery                   False
# dtype: bool

# %% [markdown]
# Drop missing data

# %%
reviews.dropna()
# Out:
#            country                                        description  \
# Unnamed: 0
# 26800           US  This opens with a pleasing toasty aroma, follo...
# 78536           US  Amidst cola and sassafras on the nose, there's...
# 125453          US  A blend of Ciel du Cheval and Force Majeure vi...
# 96340           US  This cool climate region is well-suited to thi...
# 1472            US  This varietal Cabernet Sauvignon hails from th...
# ...            ...                                                ...
# 66792           US  An elegant debut for this new Oregon winery, t...
# 101233          US  Tart and tannic, this has a sleek, almost stee...
# 13197           US  This smells like sweet red cherries and ripe p...
# 40594           US  This tasty, toasty red wine is all Sangiovese....
# 34144           US  This pure Malbec carries spicy, slightly gamy ...
#
#                        designation  points  price    province  \
# Unnamed: 0
# 26800                   Five Faces      90   33.0      Oregon
# 78536          White Hawk Vineyard      89   38.0  California
# 125453                  Crazy Mary      93   48.0  Washington
# 96340                  Gorge Crest      90   28.0      Oregon
# 1472               Sievers Reserve      93   80.0  California
# ...                            ...     ...    ...         ...
# 66792            Winemaker's Cuvée      92   32.0      Oregon
# 101233                   Sentience      89   55.0      Oregon
# 13197                       Estate      86   30.0  California
# 40594                 Kiona Estate      90   29.0  Washington
# 34144       Pepper Bridge Vineyard      90   32.0  Washington
#
#                            region_1           region_2       taster_name  \
# Unnamed: 0
# 26800             Willamette Valley  Willamette Valley      Paul Gregutt
# 78536          Santa Barbara County      Central Coast     Matt Kettmann
# 125453                 Red Mountain    Columbia Valley  Sean P. Sullivan
# 96340           Columbia Gorge (OR)       Oregon Other      Paul Gregutt
# 1472                    Napa Valley               Napa    Virginie Boone
# ...                             ...                ...               ...
# 66792             Willamette Valley  Willamette Valley      Paul Gregutt
# 101233             Applegate Valley    Southern Oregon      Paul Gregutt
# 13197              Livermore Valley      Central Coast        Jim Gordon
# 40594                  Red Mountain    Columbia Valley      Paul Gregutt
# 34144       Walla Walla Valley (WA)    Columbia Valley      Paul Gregutt
#
#            taster_twitter_handle  \
# Unnamed: 0
# 26800                @paulgwine
# 78536              @mattkettmann
# 125453             @wawinereport
# 96340                @paulgwine
# 1472                     @vboone
# ...                          ...
# 66792                @paulgwine
# 101233               @paulgwine
# 13197           @gordone_cellars
# 40594                @paulgwine
# 34144                @paulgwine
#
#                                                         title  \
# Unnamed: 0
# 26800       Fullerton 2014 Five Faces Pinot Noir (Willamet...
# 78536       Deep Sea 2011 White Hawk Vineyard Syrah (Santa...
# 125453      Mark Ryan 2012 Crazy Mary Mourvèdre (Red Mount...
# 96340       Phelps Creek 2015 Gorge Crest Gewürztraminer (...
# 1472        Volker Eisele Family Estate 2013 Sievers Reser...
# ...                                                       ...
# 66792       Elizabeth Chambers 2011 Winemaker's Cuvée Pino...
# 101233        Cowhorn 2011 Sentience Syrah (Applegate Valley)
# 13197        Fenestra 2011 Estate Grenache (Livermore Valley)
# 40594       Barrister 2011 Kiona Estate Sangiovese (Red Mo...
# 34144       Walla Walla Vintners 2009 Pepper Bridge Vineya...
#
#                        variety                       winery
# Unnamed: 0
# 26800               Pinot Noir                    Fullerton
# 78536                    Syrah                     Deep Sea
# 125453               Mourvèdre                    Mark Ryan
# 96340           Gewürztraminer                 Phelps Creek
# 1472        Cabernet Sauvignon  Volker Eisele Family Estate
# ...                        ...                          ...
# 66792               Pinot Noir           Elizabeth Chambers
# 101233                   Syrah                      Cowhorn
# 13197                 Grenache                     Fenestra
# 40594               Sangiovese                    Barrister
# 34144                   Malbec         Walla Walla Vintners
#
# [10017 rows x 13 columns]

# %% [markdown]
# #### Exercise
#
# Create a "sub"-DataFrame from `reviews` that contains the `country`, `province`, `region_1` and `region_2` columns with index labels `10`, `750` and `1200`.

# %%
sub = reviews.iloc[[10,750,1200], :]
print(sub)

r
# Out:
#      country                                        description  \
# 10        US  Amidst cola and sassafras on the nose, there's...
# 750   France  There's a green edge to this wine that struggl...
# 1200      US  Full-bodied in apple and pineapple aromas at f...
#
#               designation  points  price              province  \
# 10    White Hawk Vineyard      89   38.0            California
# 750   Le Dog de Jean Marc      84   11.0  Languedoc-Roussillon
# 1200               Hybrid      81   10.0            California
#
#                   region_1        region_2     taster_name  \
# 10    Santa Barbara County   Central Coast   Matt Kettmann
# 750       Vin de Pays d'Oc             NaN   Lauren Buzzeo
# 1200                  Lodi  Central Valley  Virginie Boone
#
#      taster_twitter_handle                                              title  \
# 10           @mattkettmann  Deep Sea 2011 White Hawk Vineyard Syrah (Santa...
# 750              @laurbuzz  Mont Tauch 2009 Le Dog de Jean Marc Merlot (Vi...
# 1200               @vboone              Peltier 2012 Hybrid Chardonnay (Lodi)
#
#          variety      winery
# 10         Syrah    Deep Sea
# 750       Merlot  Mont Tauch
# 1200  Chardonnay     Peltier

# %% [markdown]
# Create a "sub"-DataFrame from `reviews` that contains all reviews with at least 95 points for wines from oceanian countries (Australia and New Zealand).

# %%
reviews.loc[(reviews.country.isin (["Australia", "New Zealand"]) & reviews.points >= 95)]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %% [markdown]
# ### Summary Functions
#
# Summary functions allow us to quickly describe and understand a dataset by computing key statistics. Common examples include `.mean()`, `.median()`, `.min()`, `.max()`, and `.sum()` for numerical data, as well as `.value_counts()` for categorical data. These functions can be applied to entire DataFrames or specific columns, giving us insights such as average values, distributions, and totals. Using `.describe()` provides a convenient overview of multiple summary statistics at once.

# %%
reviews.describe()
# Out:
#              points         price
# count  58487.000000  54404.000000
# mean      88.442440     35.537222
# std        3.052034     42.727141
# min       80.000000      4.000000
# 25%       86.000000     17.000000
# 50%       88.000000     25.000000
# 75%       91.000000     42.000000
# max      100.000000   2500.000000

# %%
reviews.taster_name.describe()
# Out:
# count          46635
# unique            19
# top       Roger Voss
# freq           11631
# Name: taster_name, dtype: object

# %%
reviews.country.unique()
# Out:
# array(['Australia', 'France', 'Spain', 'US', 'Italy', 'Portugal',
#        'Germany', 'Chile', 'Argentina', 'South Africa', 'Georgia',
#        'Austria', 'New Zealand', 'Uruguay', 'Turkey', 'Canada',
#        'Bulgaria', 'Israel', 'Greece', 'Hungary', 'Ukraine', 'England',
#        'Moldova', 'Croatia', nan, 'Mexico', 'Romania', 'Macedonia',
#        'Morocco', 'Slovenia', 'Brazil', 'Lebanon', 'Luxembourg', 'Cyprus',
#        'Peru', 'Czech Republic', 'Serbia', 'India', 'Armenia', 'Egypt',
#        'Bosnia and Herzegovina', 'Switzerland'], dtype=object)

# %% [raw]
# reviews.country.value_counts()

# %% [markdown]
# For numerical columns, we can obtain the mean, median, min, max and sum
#
# Useful for obtaining quick statistics

# %%
reviews.price.mean()
print("The Mean of the price column is:", reviews.price.mean())
# Out:
# The Mean of the price column is: 35.537221527828834

# %% [markdown]
# ## All Done!
